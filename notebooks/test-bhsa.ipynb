# %% [markdown]
# # Test BHSA Dataset
#
# This notebook loads and explores the BHSA (Biblia Hebraica Stuttgartensia Amstelodamensis) dataset.

# %%
from cfabric.core.fabric import Fabric

# %%
# Load the BHSA dataset
CF = Fabric(locations='/Users/cody/github/etcbc/bhsa/tf/2021/')
# Out:
# M otext                from ~/github/etcbc/bhsa/tf/2021

# %%
# Explore available features
CF.explore()
# Out:
# M book                 from ~/github/etcbc/bhsa/tf/2021
# M book@am              from ~/github/etcbc/bhsa/tf/2021
# M book@ar              from ~/github/etcbc/bhsa/tf/2021
# M book@bn              from ~/github/etcbc/bhsa/tf/2021
# M book@da              from ~/github/etcbc/bhsa/tf/2021
# M book@de              from ~/github/etcbc/bhsa/tf/2021
# M book@el              from ~/github/etcbc/bhsa/tf/2021
# M book@en              from ~/github/etcbc/bhsa/tf/2021
# M book@es              from ~/github/etcbc/bhsa/tf/2021
# M book@fa              from ~/github/etcbc/bhsa/tf/2021
# M book@fr              from ~/github/etcbc/bhsa/tf/2021
# M book@he              from ~/github/etcbc/bhsa/tf/2021
# M book@hi              from ~/github/etcbc/bhsa/tf/2021
# M book@id              from ~/github/etcbc/bhsa/tf/2021
# M book@ja              from ~/github/etcbc/bhsa/tf/2021
# M book@ko              from ~/github/etcbc/bhsa/tf/2021
# M book@la              from ~/github/etcbc/bhsa/tf/2021
# M book@nl              from ~/github/etcbc/bhsa/tf/2021
# M book@pa              from ~/github/etcbc/bhsa/tf/2021
# M book@pt              from ~/github/etcbc/bhsa/tf/2021
# M book@ru              from ~/github/etcbc/bhsa/tf/2021
# M book@sw              from ~/github/etcbc/bhsa/tf/2021
# M book@syc             from ~/github/etcbc/bhsa/tf/2021
# M book@tr              from ~/github/etcbc/bhsa/tf/2021
# M book@ur              from ~/github/etcbc/bhsa/tf/2021
# M book@yo              from ~/github/etcbc/bhsa/tf/2021
# M book@zh              from ~/github/etcbc/bhsa/tf/2021
# M chapter              from ~/github/etcbc/bhsa/tf/2021
# M code                 from ~/github/etcbc/bhsa/tf/2021
# M det                  from ~/github/etcbc/bhsa/tf/2021
# M dist                 from ~/github/etcbc/bhsa/tf/2021
# M dist_unit            from ~/github/etcbc/bhsa/tf/2021
# M distributional_parent from ~/github/etcbc/bhsa/tf/2021
# M domain               from ~/github/etcbc/bhsa/tf/2021
# M freq_lex             from ~/github/etcbc/bhsa/tf/2021
# M freq_occ             from ~/github/etcbc/bhsa/tf/2021
# M function             from ~/github/etcbc/bhsa/tf/2021
# M functional_parent    from ~/github/etcbc/bhsa/tf/2021
# M g_cons               from ~/github/etcbc/bhsa/tf/2021
# M g_cons_utf8          from ~/github/etcbc/bhsa/tf/2021
# M g_lex                from ~/github/etcbc/bhsa/tf/2021
# M g_lex_utf8           from ~/github/etcbc/bhsa/tf/2021
# M g_nme                from ~/github/etcbc/bhsa/tf/2021
# M g_nme_utf8           from ~/github/etcbc/bhsa/tf/2021
# M g_pfm                from ~/github/etcbc/bhsa/tf/2021
# M g_pfm_utf8           from ~/github/etcbc/bhsa/tf/2021
# M g_prs                from ~/github/etcbc/bhsa/tf/2021
# M g_prs_utf8           from ~/github/etcbc/bhsa/tf/2021
# M g_uvf                from ~/github/etcbc/bhsa/tf/2021
# M g_uvf_utf8           from ~/github/etcbc/bhsa/tf/2021
# M g_vbe                from ~/github/etcbc/bhsa/tf/2021
# M g_vbe_utf8           from ~/github/etcbc/bhsa/tf/2021
# M g_vbs                from ~/github/etcbc/bhsa/tf/2021
# M g_vbs_utf8           from ~/github/etcbc/bhsa/tf/2021
# M g_word               from ~/github/etcbc/bhsa/tf/2021
# M g_word_utf8          from ~/github/etcbc/bhsa/tf/2021
# M gloss                from ~/github/etcbc/bhsa/tf/2021
# M gn                   from ~/github/etcbc/bhsa/tf/2021
# M instruction          from ~/github/etcbc/bhsa/tf/2021
# M is_root              from ~/github/etcbc/bhsa/tf/2021
# M kind                 from ~/github/etcbc/bhsa/tf/2021
# M kq_hybrid            from ~/github/etcbc/bhsa/tf/2021
# M kq_hybrid_utf8       from ~/github/etcbc/bhsa/tf/2021
# M label                from ~/github/etcbc/bhsa/tf/2021
# M language             from ~/github/etcbc/bhsa/tf/2021
# M languageISO          from ~/github/etcbc/bhsa/tf/2021
# M lex                  from ~/github/etcbc/bhsa/tf/2021
# M lex0                 from ~/github/etcbc/bhsa/tf/2021
# M lex_utf8             from ~/github/etcbc/bhsa/tf/2021
# M lexeme_count         from ~/github/etcbc/bhsa/tf/2021
# M ls                   from ~/github/etcbc/bhsa/tf/2021
# M mother               from ~/github/etcbc/bhsa/tf/2021
# M mother_object_type   from ~/github/etcbc/bhsa/tf/2021
# M nametype             from ~/github/etcbc/bhsa/tf/2021
# M nme                  from ~/github/etcbc/bhsa/tf/2021
# M nu                   from ~/github/etcbc/bhsa/tf/2021
# M number               from ~/github/etcbc/bhsa/tf/2021
# M omap@2017-2021       from ~/github/etcbc/bhsa/tf/2021
# M omap@c-2021          from ~/github/etcbc/bhsa/tf/2021
# M oslots               from ~/github/etcbc/bhsa/tf/2021
# M otext                from ~/github/etcbc/bhsa/tf/2021
# M otype                from ~/github/etcbc/bhsa/tf/2021
# M pargr                from ~/github/etcbc/bhsa/tf/2021
# M pdp                  from ~/github/etcbc/bhsa/tf/2021
# M pfm                  from ~/github/etcbc/bhsa/tf/2021
# M prs                  from ~/github/etcbc/bhsa/tf/2021
# M prs_gn               from ~/github/etcbc/bhsa/tf/2021
# M prs_nu               from ~/github/etcbc/bhsa/tf/2021
# M prs_ps               from ~/github/etcbc/bhsa/tf/2021
# M ps                   from ~/github/etcbc/bhsa/tf/2021
# M qere                 from ~/github/etcbc/bhsa/tf/2021
# M qere_trailer         from ~/github/etcbc/bhsa/tf/2021
# M qere_trailer_utf8    from ~/github/etcbc/bhsa/tf/2021
# M qere_utf8            from ~/github/etcbc/bhsa/tf/2021
# M rank_lex             from ~/github/etcbc/bhsa/tf/2021
# M rank_occ             from ~/github/etcbc/bhsa/tf/2021
# M rela                 from ~/github/etcbc/bhsa/tf/2021
# M root                 from ~/github/etcbc/bhsa/tf/2021
# M sp                   from ~/github/etcbc/bhsa/tf/2021
# M st                   from ~/github/etcbc/bhsa/tf/2021
# M suffix_gender        from ~/github/etcbc/bhsa/tf/2021
# M suffix_number        from ~/github/etcbc/bhsa/tf/2021
# M suffix_person        from ~/github/etcbc/bhsa/tf/2021
# M tab                  from ~/github/etcbc/bhsa/tf/2021
# M trailer              from ~/github/etcbc/bhsa/tf/2021
# M trailer_utf8         from ~/github/etcbc/bhsa/tf/2021
# M txt                  from ~/github/etcbc/bhsa/tf/2021
# M typ                  from ~/github/etcbc/bhsa/tf/2021
# M uvf                  from ~/github/etcbc/bhsa/tf/2021
# M vbe                  from ~/github/etcbc/bhsa/tf/2021
# M vbs                  from ~/github/etcbc/bhsa/tf/2021
# M verse                from ~/github/etcbc/bhsa/tf/2021
# M voc_lex              from ~/github/etcbc/bhsa/tf/2021
# M voc_lex_utf8         from ~/github/etcbc/bhsa/tf/2021
# M vs                   from ~/github/etcbc/bhsa/tf/2021
# M vt                   from ~/github/etcbc/bhsa/tf/2021
# M __levels__           from otype, oslots, otext
# M __order__            from otype, oslots, __levels__
# M __rank__             from otype, __order__
# M __levUp__            from otype, oslots, __rank__
# M __levDown__          from otype, __levUp__, __rank__
# M __characters__       from otext
# M __boundary__         from otype, oslots, __rank__
# M __sections__         from otype, oslots, otext, __levUp__, __levDown__, __levels__, book, chapter, verse
# M __structure__        from otype, oslots, otext, __rank__, __levUp__
# Feature overview: 109 for nodes; 6 for edges; 1 configs; 9 computed
# {'computeds': ('__boundary__',
#   '__characters__',
#   '__levDown__',
#   '__levUp__',
#   '__levels__',
#   '__order__',
#   '__rank__',
#   '__sections__',
#   '__structure__'),
#  'configs': ('otext',),
#  'edges': ('distributional_parent',
#   'functional_parent',
#   'mother',
#   'omap@2017-2021',
#   'omap@c-2021',
#   'oslots'),
#  'nodes': ('book',
#   'book@am',
#   'book@ar',
#   'book@bn',
#   'book@da',
#   'book@de',
#   'book@el',
#   'book@en',
#   'book@es',
#   'book@fa',
#   'book@fr',
#   'book@he',
#   'book@hi',
#   'book@id',
#   'book@ja',
#   'book@ko',
#   'book@la',
#   'book@nl',
#   'book@pa',
#   'book@pt',
#   'book@ru',
#   'book@sw',
#   'book@syc',
#   'book@tr',
#   'book@ur',
#   'book@yo',
#   'book@zh',
#   'chapter',
#   'code',
#   'det',
#   'dist',
#   'dist_unit',
#   'domain',
#   'freq_lex',
#   'freq_occ',
#   'function',
#   'g_cons',
#   'g_cons_utf8',
#   'g_lex',
#   'g_lex_utf8',
#   'g_nme',
#   'g_nme_utf8',
#   'g_pfm',
#   'g_pfm_utf8',
#   'g_prs',
#   'g_prs_utf8',
#   'g_uvf',
#   'g_uvf_utf8',
#   'g_vbe',
#   'g_vbe_utf8',
#   'g_vbs',
#   'g_vbs_utf8',
#   'g_word',
#   'g_word_utf8',
#   'gloss',
#   'gn',
#   'instruction',
#   'is_root',
#   'kind',
#   'kq_hybrid',
#   'kq_hybrid_utf8',
#   'label',
#   'language',
#   'languageISO',
#   'lex',
#   'lex0',
#   'lex_utf8',
#   'lexeme_count',
#   'ls',
#   'mother_object_type',
#   'nametype',
#   'nme',
#   'nu',
#   'number',
#   'otype',
#   'pargr',
#   'pdp',
#   'pfm',
#   'prs',
#   'prs_gn',
#   'prs_nu',
#   'prs_ps',
#   'ps',
#   'qere',
#   'qere_trailer',
#   'qere_trailer_utf8',
#   'qere_utf8',
#   'rank_lex',
#   'rank_occ',
#   'rela',
#   'root',
#   'sp',
#   'st',
#   'suffix_gender',
#   'suffix_number',
#   'suffix_person',
#   'tab',
#   'trailer',
#   'trailer_utf8',
#   'txt',
#   'typ',
#   'uvf',
#   'vbe',
#   'vbs',
#   'verse',
#   'voc_lex',
#   'voc_lex_utf8',
#   'vs',
#   'vt')}

# %%
# Load commonly used features
api = CF.loadAll()
# Out:
# Loading from /Users/cody/github/etcbc/bhsa/tf/2021/.cfm/1
# All features loaded from .cfm format

# %%
# Set up convenient references
F = api.F  # Node features
E = api.E  # Edge features
T = api.T  # Text API
L = api.L  # Locality API
N = api.N  # Node navigation

# %% [markdown]
# ## Genesis 1:1 - בְּרֵאשִׁית

# %%
# Get Genesis 1:1
gen_1_1 = T.nodeFromSection(('Genesis', 1, 1))
print(f"Verse node: {gen_1_1}")
print(f"\nHebrew text: {T.text(gen_1_1)}")
# Out:
# Verse node: 1414389
#
# Hebrew text: בְּרֵאשִׁ֖ית בָּרָ֣א אֱלֹהִ֑ים אֵ֥ת הַשָּׁמַ֖יִם וְאֵ֥ת הָאָֽרֶץ׃

# %%
gen_1_1
# Out:
# 1414389

# %%
# Show each word with grammatical features
words = L.d(gen_1_1, otype='word')
print("Word-by-word analysis of Genesis 1:1:\n")
print(f"{'Hebrew':<15} {'Lexeme':<12} {'Gloss':<20} {'POS':<8} {'Gender':<8} {'Number'}")
print("-" * 80)
for w in words:
    hebrew = F.g_word_utf8.v(w)
    lexeme = F.lex_utf8.v(w) or F.lex.v(w)
    gloss = F.gloss.v(w) or ''
    pos = F.sp.v(w) or ''
    gender = F.gn.v(w) or ''
    number = F.nu.v(w) or ''
    print(f"{hebrew:<15} {lexeme:<12} {gloss:<20} {pos:<8} {gender:<8} {number}")
# Out:
# Word-by-word analysis of Genesis 1:1:
#
# Hebrew          Lexeme       Gloss                POS      Gender   Number
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 9
#       7 hebrew = F.g_word_utf8.v(w)
#       8 lexeme = F.lex_utf8.v(w) or F.lex.v(w)
# ----> 9 gloss = F.gloss.v(w) or ''
#      10 pos = F.sp.v(w) or ''
#      11 gender = F.gn.v(w) or ''
#
# AttributeError: 'NodeFeatures' object has no attribute 'gloss'

# %% [markdown]
# ## Psalm 23:1 - The LORD is my shepherd

# %%
# Get Psalm 23:1
ps_23_1 = T.nodeFromSection(('Psalms', 23, 1))
print(f"Hebrew: {T.text(ps_23_1)}")
print("\nWord analysis:")
for w in L.d(ps_23_1, otype='word'):
    print(f"  {F.g_word_utf8.v(w):<12} = {F.gloss.v(w) or '?'}")
# Out:
# Hebrew: מִזְמֹ֥ור לְדָוִ֑ד יְהוָ֥ה רֹ֝עִ֗י לֹ֣א אֶחְסָֽר׃
#
# Word analysis:
#   מִזְמֹ֥ור    = psalm
#   לְ           = to
#   דָוִ֑ד       = David
#   יְהוָ֥ה      = YHWH
#   רֹ֝עִ֗י      = pasture
#   לֹ֣א         = not
#   אֶחְסָֽר     = diminish

# %% [markdown]
# ## Verb Analysis - First 10 verbs in Genesis

# %%
# Find first 10 verbs in Genesis
genesis_book = T.nodeFromSection(('Genesis',))
genesis_words = L.d(genesis_book, otype='word')

verbs = [w for w in genesis_words if F.sp.v(w) == 'verb'][:10]

print("First 10 verbs in Genesis:\n")
print(f"{'Hebrew':<12} {'Lexeme':<12} {'Stem':<8} {'Tense':<8} {'Person':<8} {'Gloss'}")
print("-" * 70)
for v in verbs:
    print(f"{F.g_word_utf8.v(v):<12} {F.lex_utf8.v(v):<12} {F.vs.v(v) or '':<8} {F.vt.v(v) or '':<8} {F.ps.v(v) or '':<8} {F.gloss.v(v) or ''}")
# Out:
# First 10 verbs in Genesis:
#
# Hebrew       Lexeme       Stem     Tense    Person   Gloss
# ----------------------------------------------------------------------
# בָּרָ֣א      ברא          qal      perf     p3       create
# הָיְתָ֥ה     היה          qal      perf     p3       be
# מְרַחֶ֖פֶת   רחף          piel     ptca     unknown  shake
# יֹּ֥אמֶר     אמר          qal      wayq     p3       say
# יְהִ֣י       היה          qal      impf     p3       be
# יְהִי        היה          qal      wayq     p3       be
# יַּ֧רְא      ראה          qal      wayq     p3       see
# טֹ֑וב        טוב          qal      perf     p3       be good
# יַּבְדֵּ֣ל   בדל          hif      wayq     p3       separate
# יִּקְרָ֨א    קרא          qal      wayq     p3       call

# %% [markdown]
# ## The Shema - Deuteronomy 6:4-5

# %%
# The Shema
deut_6_4 = T.nodeFromSection(('Deuteronomy', 6, 4))
deut_6_5 = T.nodeFromSection(('Deuteronomy', 6, 5))

print("שְׁמַע יִשְׂרָאֵל - Hear, O Israel!\n")
print(f"Deut 6:4: {T.text(deut_6_4)}")
print(f"Deut 6:5: {T.text(deut_6_5)}")
# Out:
# שְׁמַע יִשְׂרָאֵל - Hear, O Israel!
#
# Deut 6:4: שְׁמַ֖ע יִשְׂרָאֵ֑ל יְהוָ֥ה אֱלֹהֵ֖ינוּ יְהוָ֥ה׀ אֶחָֽד׃
# Deut 6:5: וְאָ֣הַבְתָּ֔ אֵ֖ת יְהוָ֣ה אֱלֹהֶ֑יךָ בְּכָל־לְבָבְךָ֥ וּבְכָל־נַפְשְׁךָ֖ וּבְכָל־מְאֹדֶֽךָ׃

# %%
# The Shema
deut_6_4 = T.nodeFromSection(('Deuteronomy', 6, 4))
deut_6_5 = T.nodeFromSection(('Deuteronomy', 6, 5))

print("שְׁמַע יִשְׂרָאֵל - Hear, O Israel!\n")
print(f"Deut 6:4: {T.text(deut_6_4)}")
print(f"Deut 6:5: {T.text(deut_6_5)}")
# Out:
# שְׁמַע יִשְׂרָאֵל - Hear, O Israel!
#
# Deut 6:4: שְׁמַ֖ע יִשְׂרָאֵ֑ל יְהוָ֥ה אֱלֹהֵ֖ינוּ יְהוָ֥ה׀ אֶחָֽד׃
# Deut 6:5: וְאָ֣הַבְתָּ֔ אֵ֖ת יְהוָ֣ה אֱלֹהֶ֑יךָ בְּכָל־לְבָבְךָ֥ וּבְכָל־נַפְשְׁךָ֖ וּבְכָל־מְאֹדֶֽךָ׃

# %% [markdown]
# ## Clause Structure - Genesis 1:1

# %%
# Explore clause and phrase structure of Genesis 1:1
clauses = L.d(gen_1_1, otype='clause')
print(f"Clauses in Genesis 1:1: {len(clauses)}\n")

for clause in clauses:
    clause_type = F.typ.v(clause)
    print(f"Clause (type={clause_type}):")
    
    phrases = L.d(clause, otype='phrase')
    for phrase in phrases:
        phrase_type = F.typ.v(phrase)
        phrase_func = F.function.v(phrase)
        phrase_words = [F.g_word_utf8.v(w) for w in L.d(phrase, otype='word')]
        print(f"  Phrase [{phrase_func}] ({phrase_type}): {' '.join(phrase_words)}")
# Out:
# Clauses in Genesis 1:1: 1
#
# Clause (type=xQtX):
#   Phrase [Time] (PP): בְּ רֵאשִׁ֖ית
#   Phrase [Pred] (VP): בָּרָ֣א
#   Phrase [Subj] (NP): אֱלֹהִ֑ים
#   Phrase [Objc] (PP): אֵ֥ת הַ שָּׁמַ֖יִם וְ אֵ֥ת הָ אָֽרֶץ

# %% [markdown]
# ## Corpus Statistics

# %%
# Corpus statistics
from collections import Counter

# Count node types
otype_counts = Counter()
for n in N.walk():
    otype_counts[F.otype.v(n)] += 1

print("BHSA Corpus Statistics:\n")
print(f"{'Node Type':<20} {'Count':>10}")
print("-" * 32)
for otype, count in sorted(otype_counts.items(), key=lambda x: -x[1]):
    print(f"{otype:<20} {count:>10,}")
# Out:
# BHSA Corpus Statistics:
#
# Node Type                 Count
# --------------------------------
# word                    426,590
# phrase_atom             267,532
# phrase                  253,203
# subphrase               113,850
# clause_atom              90,704
# clause                   88,131
# sentence_atom            64,514
# sentence                 63,717
# half_verse               45,179
# verse                    23,213
# lex                       9,230
# chapter                     929
# book                         39
